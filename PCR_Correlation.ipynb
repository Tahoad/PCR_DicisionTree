# %% [markdown]
# # To Find the Features so we use Pearson's Correlation

# %%
import pandas as pd
import numpy as np
from sklearn import datasets

file_excel_path = "C:\\Users\\tahoa\\Machine Learning\\Dic_Tree_Data(Original).xlsx"
df = pd.read_excel(file_excel_path)
print(df.head)
# Out:
# <bound method NDFrame.head of         TotalDate  KVA   TSIC RATEBILL  KW_PK  KW_PP_OP  KW_OP_H  MAX_KW  \
# 0             233  160  63109     3224  44.63     39.58    45.49   45.49
# 1            1641   50  72002     2114   7.26      4.76     7.50    7.50
# 2             374   50  37200     2114   0.00      0.00     0.00    0.00
# 3            3836   50  62909     2114   0.00      0.00     0.00    0.00
# 4            1490  400  31162     3224  12.00     11.20    13.60   13.60
# ...           ...  ...    ...      ...    ...       ...      ...     ...
# 462645       2523  500  91021     2114   2.70      0.00     0.00    2.70
# 462646       3072  100  36999     2114  19.44      3.48     2.88   19.44
# 462647        873   50  63109     2114   0.00      0.00     0.00    0.00
# 462648       1855  160  62109     3224  33.25      4.49    31.21   33.25
# 462649        301   50  62701     2114   0.00      0.00     0.00    0.00
#
# ...

# %%
dfcorr = df.corr()
dfcorr.style.background_gradient()
# Out:
# <style type="text/css">
# ...
